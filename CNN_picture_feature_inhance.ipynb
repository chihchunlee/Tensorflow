# %% [markdown]
# # 資料增強—隨機裁切

# %% [markdown]
# ## Image.open('view.jpg')開啟
# ## raw_image = np.asarray(raw_image)轉成np型態
# ## plt.imshow(raw_image)
# ## tf.random_crop(raw_image, [300,200,3]）隨機裁切300x200x3

# %%
# %matplotlib inline
import tensorflow as tf
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt 
raw_image = Image.open('view.jpg')
raw_image = np.asarray(raw_image)
print('origin image')
print(raw_image.shape)
plt.imshow(raw_image)
plt.show()

rand_crop_img = tf.random_crop(raw_image, [300,200,3])

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    img_ = sess.run(rand_crop_img)
    print('random crop')
    print(img_.shape)
    plt.imshow(img_)
    plt.show()
# Out:
# origin image
# (720, 960, 3)
# random crop
# (300, 200, 3)

# %% [markdown]
# # 資料增強—翻面

# %% [markdown]
# ## tf.image.random_flip_left_right(raw_image)

# %%
# %matplotlib inline
import tensorflow as tf
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt 
raw_image = Image.open('view.jpg')
raw_image = np.asarray(raw_image)
print('origin image')
print(raw_image.shape)
plt.imshow(raw_image)
plt.show()


flip_img = tf.image.random_flip_left_right(raw_image) # 50% will flip image


with tf.Session() as sess:

    
    img_ = sess.run(flip_img)
    print('flip')
    print(img_.shape)
    plt.imshow(img_)
    plt.show()

    
    img_ = sess.run(flip_img)
    print('flip')
    print(img_.shape)
    plt.imshow(img_)
    plt.show()
# Out:
# origin image
# (720, 960, 3)
# flip
# (720, 960, 3)
# flip
# (720, 960, 3)

# %% [markdown]
# # 資料增強—調整亮度

# %% [markdown]
# ## tf.image.adjust_brightness(raw_image, delta= 0.2) 調整delta

# %%
# %matplotlib inline
import tensorflow as tf
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt 
raw_image = Image.open('view.jpg')
raw_image = np.asarray(raw_image)
print('origin image')
print(raw_image.shape)
plt.imshow(raw_image)
plt.show()

bright_img = tf.image.adjust_brightness(raw_image, delta= 0.2)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    img_ = sess.run(bright_img)
    print('adjust brightness')
    print(img_.shape)
    plt.imshow(img_)
    plt.show()
# Out:
# origin image
# (720, 960, 3)
# adjust brightness
# (720, 960, 3)
